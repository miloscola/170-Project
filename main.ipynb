# %%
# Install packages
# %pip install networkx
# %pip install numpy
# %pip install tqdm
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# The starter code is short and simple, take a look!
from starter import *

# %% [markdown]
# # Phase 2 - Implement your Solver

# %%
def solve(G: nx.Graph):
    # TODO implement this function with your solver
    # Assign a team to v with G.nodes[v]['team'] = team_id
    # Access the team of v with team_id = G.nodes[v]['team']
    num_teams = find_optomal_team_num(G)
    pre_set(G, num_teams)
    print("old score is " + str(score(G)))
    p = get_p(G, num_teams)
    result = simulated_annealing(num_teams, p, G, 10000, score(G) * 10000, .7)
    return result

# %%
G = read_input('C:/Users/Milo/Documents/cs170/project/inputs/small.in')
a = solve(G)
validate_output(G)
visualize(G)
score(G)
# Out:
# old score is 61385.50610186581
# 6704.506101865805

# %%
run(solve, 'C:/Users/Milo/Documents/cs170/project/inputs/small.in', 'C:/Users/Milo/Documents/cs170/project/outputs/small.out', overwrite=True)
# Out:
# old score is 61385.50610186581
# C:/Users/Milo/Documents/cs170/project/inputs/small.in: cost 6203.506101865805

# %%
run_all(solve, 'C:/Users/Milo/Documents/cs170/project/inputs', 'C:/Users/Milo/Documents/cs170/project/outputs', overwrite=True)
tar('output')
# Out:
#   0%|          | 0/784 [00:00<?, ?it/s]
# old score is 62686.36969444755
# C:\Users\Milo\Documents\cs170\project\inputs\example.in: cost 7563.348621979074
# old score is 60724.81500331443
# C:\Users\Milo\Documents\cs170\project\inputs\large.in: cost 5460.815003314424
# old score is 545794.0004483488
# C:\Users\Milo\Documents\cs170\project\inputs\large1.in: cost 43404.00044834878
# old score is 456883.26224646514
# C:\Users\Milo\Documents\cs170\project\inputs\large10.in: cost 32099.320038415917
# old score is 1771219.2493960704
# C:\Users\Milo\Documents\cs170\project\inputs\large100.in: cost 4219.353456793685
# old score is 431899.00044834876
# C:\Users\Milo\Documents\cs170\project\inputs\large101.in: cost 46175.04259865841
# old score is 438503.45423265285
# C:\Users\Milo\Documents\cs170\project\inputs\large102.in: cost 114027.45423265286
# old score is 1219.2493960703473
# C:\Users\Milo\Documents\cs170\project\inputs\large103.in: cost 1219.2493960703473
# ...
